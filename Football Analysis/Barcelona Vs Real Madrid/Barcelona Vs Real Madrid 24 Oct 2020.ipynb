# 19  2021-02-12T00:19:52.866831  2021-07-27T01:39:46.037203          19
# 26  2021-02-14T16:59:10.494786  2021-07-27T01:33:28.078805          23
# 27  2021-04-12T07:10:50.227712  2021-07-27T01:25:11.305513          29
# 29     2021-05-28T13:27:02.231     2021-07-27T01:36:16.430          21
# 30  2020-11-30T09:14:36.663981  2021-07-27T01:50:06.574670          11
# 31  2021-02-22T17:44:36.917392  2021-07-27T01:32:23.014608          24
# 32  2021-02-25T05:32:07.474640  2021-07-26T15:28:42.810666           1
# 34  2020-12-09T11:00:37.864371  2021-07-27T01:56:50.756651           9
#
#    competition_stage   stadium                             referee  \
# 0     Regular Season  Camp Nou                 Adrián Cordero Vega
# 2     Regular Season  Camp Nou          Antonio Miguel Mateu Lahoz
# 4     Regular Season  Camp Nou              Pablo González Fuertes
# 5     Regular Season  Camp Nou                                 NaN
# 6     Regular Season  Camp Nou  Alejandro José Hernández Hernández
# 11    Regular Season  Camp Nou                   Jesús Gil Manzano
# 12    Regular Season  Camp Nou               Juan Martínez Munuera
# 15    Regular Season  Camp Nou          Guillermo Cuadra Fernández
# 16    Regular Season  Camp Nou        Ricardo De Burgos Bengoetxea
# 17    Regular Season  Camp Nou              Jorge Figueroa Vázquez
# 19    Regular Season  Camp Nou         José María Sánchez Martínez
# 26    Regular Season  Camp Nou              Jorge Figueroa Vázquez
# 27    Regular Season  Camp Nou                Santiago Jaime Latre
# 29    Regular Season  Camp Nou          Antonio Miguel Mateu Lahoz
# 30    Regular Season  Camp Nou          Antonio Miguel Mateu Lahoz
# 31    Regular Season  Camp Nou               Juan Martínez Munuera
# 32    Regular Season  Camp Nou       Isidro Díaz de Mera Escuderos
# 34    Regular Season  Camp Nou                                 NaN
#
#    data_version shot_fidelity_version xy_fidelity_version
# 0         1.1.0                     2                   2
# 2         1.1.0                     2                   2
# 4         1.1.0                     2                   2
# 5         1.1.0                     2                   2
# 6         1.1.0                     2                   2
# 11        1.1.0                     2                   2
# 12        1.1.0                     2                   2
# 15        1.1.0                     2                   2
# 16        1.1.0                     2                   2
# 17        1.1.0                     2                   2
# 19        1.1.0                     2                   2
# 26        1.1.0                     2                   2
# 27        1.1.0                     2                   2
# 29        1.1.0                     2                   2
# 30        1.1.0                     2                   2
# 31        1.1.0                     2                   2
# 32        1.1.0                     2                   2
# 34        1.1.0                     2                   2

# %%
events = sb.events(match_id=3773585)
# Out:
# credentials were not supplied. open data access only

# %%
events.head()
# Out:
#   bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                NaN                  NaN                            NaN
# 1                NaN                  NaN                            NaN
# 2                NaN                  NaN                            NaN
# 3                NaN                  NaN                            NaN
# 4                NaN                  NaN                            NaN
#
#   block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0              NaN             NaN                NaN                  NaN
# 1              NaN             NaN                NaN                  NaN
# 2              NaN             NaN                NaN                  NaN
# 3              NaN             NaN                NaN                  NaN
# 4              NaN             NaN                NaN                  NaN
#
#   clearance_body_part clearance_head clearance_left_foot  ...  \
# 0                 NaN            NaN                 NaN  ...
# 1                 NaN            NaN                 NaN  ...
# 2                 NaN            NaN                 NaN  ...
# 3                 NaN            NaN                 NaN  ...
# 4                 NaN            NaN                 NaN  ...
#
#   shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0               NaN            NaN       NaN                  NaN
# 1               NaN            NaN       NaN                  NaN
# 2               NaN            NaN       NaN                  NaN
# 3               NaN            NaN       NaN                  NaN
# 4               NaN            NaN       NaN                  NaN
#
#   substitution_replacement                                            tactics  \
# 0                      NaN  {'formation': 442, 'lineup': [{'player': {'id'...
# 1                      NaN  {'formation': 433, 'lineup': [{'player': {'id'...
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
#
#           team     timestamp         type under_pressure
# 0    Barcelona  00:00:00.000  Starting XI            NaN
# 1  Real Madrid  00:00:00.000  Starting XI            NaN
# 2    Barcelona  00:00:00.000   Half Start            NaN
# 3  Real Madrid  00:00:00.000   Half Start            NaN
# 4  Real Madrid  00:00:00.000   Half Start            NaN
#
# [5 rows x 89 columns]

# %%
events.columns
# Out:
# Index(['bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_penalty', 'foul_committed_type',
#        'foul_won_advantage', 'foul_won_defensive', 'foul_won_penalty',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'injury_stoppage_in_chain', 'interception_outcome', 'location',
#        'match_id', 'minute', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
#        'pass_cut_back', 'pass_deflected', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_inswinging', 'pass_length',
#        'pass_no_touch', 'pass_outcome', 'pass_outswinging', 'pass_recipient',
#        'pass_shot_assist', 'pass_switch', 'pass_technique',
#        'pass_through_ball', 'pass_type', 'period', 'play_pattern', 'player',
#        'player_id', 'position', 'possession', 'possession_team',
#        'possession_team_id', 'related_events', 'second', 'shot_aerial_won',
#        'shot_body_part', 'shot_end_location', 'shot_first_time',
#        'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one',
#        'shot_outcome', 'shot_statsbomb_xg', 'shot_technique', 'shot_type',
#        'substitution_outcome', 'substitution_replacement', 'tactics', 'team',
#        'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
columns = ['team', 'player', 'player_id', 'minute', 'location', 'pass_end_location', 'type', 'pass_outcome', 'shot_statsbomb_xg', 'shot_outcome']
events = events[columns]

# %%
pass_events = events[events['type'] == 'Pass'].reset_index()

# %%
pass_events['pass_outcome'] = pass_events['pass_outcome'].fillna('Complete')

# %%
x = []
y = []
x_end = []
y_end = []
for i in range(len(pass_events['location'])):
    x.append(pass_events['location'][i][0])
    y.append(pass_events['location'][i][1])
    
for i in range(len(pass_events['pass_end_location'])):
    x_end.append(pass_events['pass_end_location'][i][0])
    y_end.append(pass_events['pass_end_location'][i][1])

# %%
pass_events['x'] = x
pass_events['y'] = y
pass_events['x_end'] = x_end
pass_events['y_end'] = y_end

# %%
pass_events = pass_events.drop(['location', 'pass_end_location'], axis=1)

# %%
pass_events[pass_events['team'] == 'Barcelona']
# Out:
#       index       team                                            player  \
# 24       30  Barcelona                                   Clément Lenglet
# 25       31  Barcelona                                  Jordi Alba Ramos
# 26       32  Barcelona                                   Frenkie de Jong
# 27       33  Barcelona                    Lionel Andrés Messi Cuccittini
# 28       34  Barcelona                                    Anssumane Fati
# ...     ...        ...                                               ...
# 1168   1174  Barcelona  Francisco António Machado Mota de Castro Trincão
# 1169   1175  Barcelona                                      Sergino Dest
# 1178   1184  Barcelona                             Gerard Piqué Bernabéu
# 1190   1196  Barcelona                                   Frenkie de Jong
# 1191   1197  Barcelona                         Philippe Coutinho Correia
#
#       player_id  minute  type pass_outcome  shot_statsbomb_xg shot_outcome  \
# 24       6826.0       1  Pass     Complete                NaN          NaN
# 25       5211.0       1  Pass     Complete                NaN          NaN
# 26       8118.0       1  Pass     Complete                NaN          NaN
# 27       5503.0       1  Pass     Complete                NaN          NaN
# 28      30756.0       1  Pass     Complete                NaN          NaN
# ...         ...     ...   ...          ...                ...          ...
# 1168    22390.0      93  Pass     Complete                NaN          NaN
# 1169    21881.0      93  Pass   Incomplete                NaN          NaN
# 1178     5213.0      93  Pass   Incomplete                NaN          NaN
# 1190     8118.0      94  Pass     Complete                NaN          NaN
# 1191     3501.0      94  Pass     Complete                NaN          NaN
#
#          x     y  x_end  y_end
# 24     2.8  10.7   15.3    2.0
# 25    16.0   2.0   28.6   14.1
# 26    34.9  16.3   51.4   24.2
# 27    51.1  30.9   58.1   45.1
# 28    58.1  45.1   56.9   68.1
# ...    ...   ...    ...    ...
# 1168  70.0  63.2   49.2   71.9
# 1169  50.8  71.9   79.6   70.8
# 1178  58.9  59.9   67.7   41.3
# 1190  33.8  39.2   36.6   52.3
# 1191  36.6  52.9   51.9   44.7
#
# [626 rows x 13 columns]

# %%
pass_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              1203 non-null   int64
#  1   team               1203 non-null   object
#  2   player             1203 non-null   object
#  3   player_id          1203 non-null   float64
#  4   minute             1203 non-null   int64
#  5   type               1203 non-null   object
#  6   pass_outcome       1203 non-null   object
#  7   shot_statsbomb_xg  0 non-null      float64
#  8   shot_outcome       0 non-null      object
#  9   x                  1203 non-null   float64
#  10  y                  1203 non-null   float64
#  11  x_end              1203 non-null   float64
#  12  y_end              1203 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 122.3+ KB

# %%
fig, ax = plt.subplots(figsize=(13,10))
pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='grass', stripe=True, 
              orientation='horizontal', constrained_layout=True)
pitch.draw(ax=ax)
# pitch.draw(ax=ax[1])
# ax[0].invert_xaxis()
# ax[1].invert_xaxis()
# ax[1].invert_yaxis()

frenkie = pass_events[pass_events['player'] == 'Frenkie de Jong']
kde = sns.kdeplot(frenkie['y'], frenkie['x'], shade=True, shade_lowest=False, alpha=.5, ax=ax,  cmap='magma')

toni = pass_events[pass_events['player'] == 'Toni Kroos']
kde = sns.kdeplot(toni['y'], toni['x'], shade=True, shade_lowest=False, alpha=.5, ax=ax)

for i in range(len(pass_events['x'])):
    if pass_events['player'][i] == 'Frenkie de Jong':
        ax.scatter(pass_events['y'][i], pass_events['x'][i], color='Blue')
    elif pass_events['player'][i] == 'Toni Kroos':
        ax.scatter(pass_events['y'][i], pass_events['x'][i], color='White')
        
plt.title('Frenkie De Jong Vs Toni Kroos Pass Events')
# Out:
# C:\Users\Dodhy\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Dodhy\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Frenkie De Jong Vs Toni Kroos Pass Events')

# %%
np.unique(pass_events[pass_events['team'] == 'Barcelona']['player'])
# Out:
# array(['Anssumane Fati', 'Antoine Griezmann', 'Clément Lenglet',
#        'Francisco António Machado Mota de Castro Trincão',
#        'Frenkie de Jong', 'Gerard Piqué Bernabéu', 'Jordi Alba Ramos',
#        'Lionel Andrés Messi Cuccittini', 'Martin Braithwaite Christensen',
#        'Norberto Murara Neto', 'Ousmane Dembélé', 'Pedro González López',
#        'Philippe Coutinho Correia', 'Sergino Dest',
#        'Sergio Busquets i Burgos'], dtype=object)

# %% [markdown]
# ## Expected Goals

# %%
xgoals_event = events[events['shot_statsbomb_xg'].notnull()].reset_index()

# %%
xgoals_event.head(10)
# Out:
#    index         team                                   player  player_id  \
# 0   3989  Real Madrid       Federico Santiago Valverde Dipetta     6773.0
# 1   3990  Real Madrid  Vinícius José Paixão de Oliveira Júnior    18395.0
# 2   3991    Barcelona                           Anssumane Fati    30756.0
# 3   3992    Barcelona                Philippe Coutinho Correia     3501.0
# 4   3993    Barcelona                Philippe Coutinho Correia     3501.0
# 5   3994    Barcelona           Lionel Andrés Messi Cuccittini     5503.0
# 6   3995  Real Madrid                           Raphaël Varane     5485.0
# 7   3996  Real Madrid                      Sergio Ramos García     5201.0
# 8   3997    Barcelona           Lionel Andrés Messi Cuccittini     5503.0
# 9   3998  Real Madrid                            Karim Benzema    19677.0
#
#    minute       location pass_end_location  type pass_outcome  \
# 0       4  [109.9, 49.3]               NaN  Shot          NaN
# 1       6  [107.6, 37.9]               NaN  Shot          NaN
# 2       7  [114.8, 36.5]               NaN  Shot          NaN
# 3      12   [97.5, 22.1]               NaN  Shot          NaN
# 4      14   [97.3, 30.5]               NaN  Shot          NaN
# 5      18   [94.3, 31.8]               NaN  Shot          NaN
# 6      22  [113.6, 37.8]               NaN  Shot          NaN
# 7      22  [113.2, 36.5]               NaN  Shot          NaN
# 8      23  [113.1, 47.8]               NaN  Shot          NaN
# 9      23  [106.6, 39.8]               NaN  Shot          NaN
#
#    shot_statsbomb_xg shot_outcome
# 0           0.367100         Goal
# 1           0.190835        Off T
# 2           0.365539         Goal
# 3           0.014535      Blocked
# 4           0.028745        Saved
# 5           0.048289        Saved
# 6           0.167383      Blocked
# 7           0.089730        Saved
# 8           0.361797        Saved
# 9           0.362742        Saved

# %%
xgoals_event = xgoals_event.drop(['pass_end_location', 'pass_outcome'], axis=1)

# %%
x_shot = []
y_shot = []
for i in range(len(xgoals_event['location'])):
    x_shot.append(xgoals_event['location'][i][0])
    y_shot.append(xgoals_event['location'][i][1])
    
xgoals_event['x'] = x_shot
xgoals_event['y'] = y_shot

# %%
madrid_goals= xgoals_event[xgoals_event['team'] == 'Real Madrid'][xgoals_event['shot_outcome'] == 'Goal'].count()['shot_outcome']
bfc_goals = xgoals_event[xgoals_event['team'] == 'Barcelona'][xgoals_event['shot_outcome'] == 'Goal'].count()['shot_outcome']

# %%
# membuat pitch xGoal
fig, ax = plt.subplots(figsize=(13.5, 8))
fig.set_facecolor('#22312b')
# ax.patch.set_facecolor('#22312b')

pitch = Pitch(pitch_type='statsbomb', orientation='horizontal', 
              pitch_color='grass', line_color='white', stripe=True, figsize=(16,11), constrained_layout=True,
             tight_layout=False, tick=True, label=True)
pitch.draw(ax=ax)
plt.gca().invert_yaxis()
annotation = ax.annotate("Real Madrid "+str(madrid_goals) + " - " + str(bfc_goals) + " Barcelona", (59,70),fontsize=30, ha='center')
plt.title('Barcelona Vs Real Madrid xGoal Map', color='White', size=20)

for i in range(len(xgoals_event['x'])):
    if xgoals_event['team'][i] == 'Barcelona':
        if xgoals_event['shot_outcome'][i] == 'Goal':
            plt.scatter(xgoals_event['x'][i], xgoals_event['y'][i], color='yellow', s=xgoals_event['shot_statsbomb_xg'][i]*1000)
        else:
            plt.scatter(xgoals_event['x'][i], xgoals_event['y'][i], color='blue', s=xgoals_event['shot_statsbomb_xg'][i]*1000)
    elif xgoals_event['team'][i] == 'Real Madrid':
        if xgoals_event['shot_outcome'][i] == 'Goal':
            plt.scatter((xgoals_event['x'][i]/12), xgoals_event['y'][i], color='yellow', s=xgoals_event['shot_statsbomb_xg'][i]*1000)
        else:
            plt.scatter((xgoals_event['x'][i]/12), xgoals_event['y'][i], color='white', s=xgoals_event['shot_statsbomb_xg'][i]*1000)

# %%
xgoals_event
# Out:
#     index         team                                   player  player_id  \
# 0    3989  Real Madrid       Federico Santiago Valverde Dipetta     6773.0
# 1    3990  Real Madrid  Vinícius José Paixão de Oliveira Júnior    18395.0
# 2    3991    Barcelona                           Anssumane Fati    30756.0
# 3    3992    Barcelona                Philippe Coutinho Correia     3501.0
# 4    3993    Barcelona                Philippe Coutinho Correia     3501.0
# 5    3994    Barcelona           Lionel Andrés Messi Cuccittini     5503.0
# 6    3995  Real Madrid                           Raphaël Varane     5485.0
# 7    3996  Real Madrid                      Sergio Ramos García     5201.0
# 8    3997    Barcelona           Lionel Andrés Messi Cuccittini     5503.0
# 9    3998  Real Madrid                            Karim Benzema    19677.0
# 10   3999  Real Madrid                            Karim Benzema    19677.0
# 11   4000  Real Madrid                      Sergio Ramos García     5201.0
# 12   4001  Real Madrid                 Carlos Henrique Casimiro     5539.0
# 13   4002    Barcelona                           Anssumane Fati    30756.0
# 14   4003    Barcelona                Philippe Coutinho Correia     3501.0
# 15   4004  Real Madrid                            Karim Benzema    19677.0
# 16   4005  Real Madrid                      Sergio Ramos García     5201.0
# 17   4006    Barcelona                Philippe Coutinho Correia     3501.0
# 18   4007    Barcelona                Philippe Coutinho Correia     3501.0
# 19   4008    Barcelona           Lionel Andrés Messi Cuccittini     5503.0
# 20   4009  Real Madrid                               Toni Kroos     5574.0
# 21   4010  Real Madrid                               Toni Kroos     5574.0
# 22   4011  Real Madrid                      Sergio Ramos García     5201.0
# 23   4012  Real Madrid                           Raphaël Varane     5485.0
# 24   4013  Real Madrid  Vinícius José Paixão de Oliveira Júnior    18395.0
# 25   4014  Real Madrid                              Luka Modrić     5463.0
#
#     minute       location  type  shot_statsbomb_xg shot_outcome      x     y
# 0        4  [109.9, 49.3]  Shot           0.367100         Goal  109.9  49.3
# 1        6  [107.6, 37.9]  Shot           0.190835        Off T  107.6  37.9
# 2        7  [114.8, 36.5]  Shot           0.365539         Goal  114.8  36.5
# 3       12   [97.5, 22.1]  Shot           0.014535      Blocked   97.5  22.1
# 4       14   [97.3, 30.5]  Shot           0.028745        Saved   97.3  30.5
# 5       18   [94.3, 31.8]  Shot           0.048289        Saved   94.3  31.8
# 6       22  [113.6, 37.8]  Shot           0.167383      Blocked  113.6  37.8
# 7       22  [113.2, 36.5]  Shot           0.089730        Saved  113.2  36.5
# 8       23  [113.1, 47.8]  Shot           0.361797        Saved  113.1  47.8
# 9       23  [106.6, 39.8]  Shot           0.362742        Saved  106.6  39.8
# 10      35  [102.7, 40.2]  Shot           0.060982      Blocked  102.7  40.2
# 11      47  [112.3, 44.1]  Shot           0.087912        Off T  112.3  44.1
# 12      50   [85.3, 43.7]  Shot           0.011588        Off T   85.3  43.7
# 13      51  [108.8, 53.6]  Shot           0.051994        Off T  108.8  53.6
# 14      53  [112.2, 31.3]  Shot           0.061682        Off T  112.2  31.3
# 15      56  [102.8, 26.8]  Shot           0.054485        Off T  102.8  26.8
# 16      62  [107.7, 39.8]  Shot           0.760000         Goal  107.7  39.8
# 17      66  [105.8, 27.2]  Shot           0.035138      Blocked  105.8  27.2
# 18      69  [109.8, 37.3]  Shot           0.110588      Blocked  109.8  37.3
# 19      78   [91.6, 43.0]  Shot           0.044264      Blocked   91.6  43.0
# 20      85  [104.5, 44.2]  Shot           0.160876        Saved  104.5  44.2
# 21      85  [114.2, 48.2]  Shot           0.137654        Saved  114.2  48.2
# 22      85  [112.5, 33.5]  Shot           0.246106        Saved  112.5  33.5
# 23      85  [112.3, 41.6]  Shot           0.211937        Off T  112.3  41.6
# 24      86   [94.0, 40.3]  Shot           0.045235        Saved   94.0  40.3
# 25      89  [105.4, 42.2]  Shot           0.466651         Goal  105.4  42.2

# %%
a_xg = [0]
h_xg = [0]
a_time = [0]
h_time = [0]

# %%
hteam = xgoals_event[xgoals_event['team'] == 'Real Madrid'].reset_index()
ateam = xgoals_event[xgoals_event['team'] == 'Barcelona'].reset_index()

# %%
for x in range(len(xgoals_event['shot_statsbomb_xg'])):
    if xgoals_event['team'][x] == 'Real Madrid':
        h_xg.append(xgoals_event['shot_statsbomb_xg'][x])
        h_time.append(xgoals_event['minute'][x])
    elif xgoals_event['team'][x] == 'Barcelona':
        a_xg.append(xgoals_event['shot_statsbomb_xg'][x])
        a_time.append(xgoals_event['minute'][x])

# %%
def nums_list_cumulative(nums_list):
    return [sum(nums_list[:i+1]) for i in range(len(nums_list))]

h_cumulative = nums_list_cumulative(h_xg)
a_cumulative = nums_list_cumulative(a_xg)

# %%
h_cumulative
# Out:
# [0,
#  0.36710012,
#  0.55793542,
#  0.72531852,
#  0.81504811,
#  1.17779021,
#  1.23877207,
#  1.3266842699999999,
#  1.338272502,
#  1.3927570919999999,
#  2.152757092,
#  2.313633092,
#  2.451286802,
#  2.697392752,
#  2.909329332,
#  2.954563938,
#  3.421214898]

# %%
hgoals = []
agoals = []
hgoals_minute = []
agoals_minute = []

for i in range(len(hteam['shot_outcome'])):
    if hteam['shot_outcome'][i] == 'Goal':
        hgoals.append(h_cumulative[i+1])
        hgoals_minute.append(h_time[i+1])

# %%
for i in range(len(ateam['shot_outcome'])):
    if ateam['shot_outcome'][i] == 'Goal':
        agoals.append(a_cumulative[i+1])
        agoals_minute.append(a_time[i+1])

# %%
hteam
# Out:
#     level_0  index         team                                   player  \
# 0         0   3989  Real Madrid       Federico Santiago Valverde Dipetta
# 1         1   3990  Real Madrid  Vinícius José Paixão de Oliveira Júnior
# 2         6   3995  Real Madrid                           Raphaël Varane
# 3         7   3996  Real Madrid                      Sergio Ramos García
# 4         9   3998  Real Madrid                            Karim Benzema
# 5        10   3999  Real Madrid                            Karim Benzema
# 6        11   4000  Real Madrid                      Sergio Ramos García
# 7        12   4001  Real Madrid                 Carlos Henrique Casimiro
# 8        15   4004  Real Madrid                            Karim Benzema
# 9        16   4005  Real Madrid                      Sergio Ramos García
# 10       20   4009  Real Madrid                               Toni Kroos
# 11       21   4010  Real Madrid                               Toni Kroos
# 12       22   4011  Real Madrid                      Sergio Ramos García
# 13       23   4012  Real Madrid                           Raphaël Varane
# 14       24   4013  Real Madrid  Vinícius José Paixão de Oliveira Júnior
# 15       25   4014  Real Madrid                              Luka Modrić
#
#     player_id  minute       location  type  shot_statsbomb_xg shot_outcome  \
# 0      6773.0       4  [109.9, 49.3]  Shot           0.367100         Goal
# 1     18395.0       6  [107.6, 37.9]  Shot           0.190835        Off T
# 2      5485.0      22  [113.6, 37.8]  Shot           0.167383      Blocked
# 3      5201.0      22  [113.2, 36.5]  Shot           0.089730        Saved
# 4     19677.0      23  [106.6, 39.8]  Shot           0.362742        Saved
# 5     19677.0      35  [102.7, 40.2]  Shot           0.060982      Blocked
# 6      5201.0      47  [112.3, 44.1]  Shot           0.087912        Off T
# 7      5539.0      50   [85.3, 43.7]  Shot           0.011588        Off T
# 8     19677.0      56  [102.8, 26.8]  Shot           0.054485        Off T
# 9      5201.0      62  [107.7, 39.8]  Shot           0.760000         Goal
# 10     5574.0      85  [104.5, 44.2]  Shot           0.160876        Saved
# 11     5574.0      85  [114.2, 48.2]  Shot           0.137654        Saved
# 12     5201.0      85  [112.5, 33.5]  Shot           0.246106        Saved
# 13     5485.0      85  [112.3, 41.6]  Shot           0.211937        Off T
# 14    18395.0      86   [94.0, 40.3]  Shot           0.045235        Saved
# 15     5463.0      89  [105.4, 42.2]  Shot           0.466651         Goal
#
#         x     y
# 0   109.9  49.3
# 1   107.6  37.9
# 2   113.6  37.8
# 3   113.2  36.5
# 4   106.6  39.8
# 5   102.7  40.2
# 6   112.3  44.1
# 7    85.3  43.7
# 8   102.8  26.8
# 9   107.7  39.8
# 10  104.5  44.2
# 11  114.2  48.2
# 12  112.5  33.5
# 13  112.3  41.6
# 14   94.0  40.3
# 15  105.4  42.2

# %%
fig, ax = plt.subplots(figsize=(16,10))
plt.xticks([0,15,30,45,60,75,90])
plt.xlabel('Minute Play')
plt.ylabel('xG')
plt.title('Real Madrid Vs Barcelona xGoal Statistic')

plt.scatter(x=hgoals_minute, y=hgoals, color='red')
plt.scatter(x=agoals_minute, y=agoals, color='red')
ax.step(x=h_time, y=h_cumulative, color='salmon')
ax.step(x=a_time, y=a_cumulative, color='blue')
